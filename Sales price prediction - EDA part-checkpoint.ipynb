# %% [markdown]
# #  OASIS INFOBYTE INTERNSHIP
#
# # TASK - 3
#
# # SALES PREDICTION USING PYTHON

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # READ DATASET

# %%
dataset=pd.read_csv('Advertising.csv')
dataset
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# #  DATASET COLUMNS AND THEIR DTYPE

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# #  CO-RELATION BETWEEN TV, RADIO AND NEWSPAPER

# %%
advertise=['TV','Radio','Newspaper']

# %%
dataset[advertise].corr()
# Out:
#                  TV     Radio  Newspaper
# TV         1.000000  0.054809   0.056648
# Radio      0.054809  1.000000   0.354104
# Newspaper  0.056648  0.354104   1.000000

# %% [markdown]
# # REMOVE UNNECESSARY COLUMN

# %%
dataset=dataset.drop(columns=['Unnamed: 0'])

# %% [markdown]
# # CHECK NULL VALUE EXISTS OR NOT

# %%
dataset.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # USING DESCRIBE()

# %%
dataset.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# # SCATTER PLOT OF TV, RADIO AND NEWSPAPER

# %%
sn.scatterplot(x='TV',y='Sales',data=dataset)
plt.title("Understand the sales on TV adversiting")
plt.show()

# %% [markdown]
# Here we determine as the money spending increase on TV, sales is also increasing.

# %%
sn.scatterplot(x='Radio',y='Sales',data=dataset)
plt.title("Understand the sales on Radio adversiting")
plt.show()

# %% [markdown]
# Here we can not come to a conclusion that if we spending more in radio sales is also increasing maybe sales is increase maybe not or maybe down

# %%
sn.scatterplot(x='Newspaper',y='Sales',data=dataset)
plt.title("Understand the sales on Newspaper adversiting")
plt.show()

# %% [markdown]
# # more invest in newspaper advertising has no particular effect on sales so we can avoid this feature

# %% [markdown]
# # CO-RELATION BETWEEN TV, RADIO, NEWSPAPER AND SALES

# %% [markdown]
# Here we determine that more money spending in newspaper can not able to able the sales

# %%
dataset.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# # HEATMAP

# %% [markdown]
# Determine the co-relation between features

# %%
sn.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Plot a Heatmap to determine the co-realtion better

# %%
sn.pairplot(dataset)
plt.show()

# %% [markdown]
# Plot a pairplot to understand the realtionships between features

# %%
dataset
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # CONVERT DATASET TO A NEW CSV FILE

# %%
dataset.to_csv('dataset.csv')
